# %% [markdown]
# # BBC News NLP
# An analysis of BBC News articles, using NLP. [Data is available here](http://mlg.ucd.ie/datasets/bbc.html).
#
# Objectives:
# * Use the full text dataset and classify each existing category into sub-categories:
#     * Breakdown ‘Business’ into stock market, company news, mergers and acquisitions etc.
#     * Breakdown ‘Entertainment’ into cinema, theatre, music, literature, personality etc.
#     * Breakdown ‘Sports’ into the type of sport: cricket, football, Olympics etc.
#     * Please create as many categories as you feel are appropriate.
# * Identify documents and extract the named entities for media personalities, clearly identifying their jobs (e.g. Politicians, TV/Film Personalities, Musicians)
# * Extract summaries of anything that took place or is/was scheduled to take place in April.

# %%
# Load Libraries
import pandas as pd
import re
import nltk
from nltk import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer as WNL
from nltk.corpus import wordnet
from string import punctuation
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.cluster import KMeans
from transformers import pipeline
import gensim
from gensim import corpora
from gensim.models import CoherenceModel
from gensim.models.ldamodel import LdaModel
import spacy
from spacy.matcher import PhraseMatcher
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Define stopwords
stopwords_list = stopwords.words("english")
stopwords_list = [*stopwords_list, *list(punctuation), *['``', "''"]]

# %%
# Load the files
parent_folder = "C:\\Users\\User\\Documents\\Projects\\BBC_News_NLP\\Data\\bbc"

# Collect each category's filepath
category_folders = [] 
for folder in os.listdir(parent_folder):
    path = os.path.join(parent_folder, folder)
    if os.path.isdir(path): # Check it is a filepath (e.g. not a README)
        category_folders.append(path)

# Identify, read and collate the .txt files within each category folder 
articles_list = [] 
for category in category_folders:
    for article in os.listdir(category):
        if article.endswith(".txt") and not article.startswith("README"): # only select relevant .txt files
            article_path = os.path.join(category, article)
            try: 
                with open(article_path, "r") as file:
                    article_text = file.read()
                        # append articles to list, noting the article category:
                    articles_list.append({"text" : article_text, "category" : os.path.relpath(category, parent_folder)})
            except: 
                print(f"Could not load {article_path}")

articles = pd.DataFrame(articles_list) # convert the articles into a dataframe

# Print the numbers of articles, and the first few rows of the data
print(f"{len(articles)} articles loaded") 
articles.head()
# Out:
# 2225 articles loaded
#                                                 text  category
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
# Check for and remove any duplicate rows
print(articles[articles.duplicated()].head())
print(f"{len(articles[articles.duplicated()])} duplicated rows") #98 duplicate rows

articles = articles.drop_duplicates()
# Out:
#                                                   text  category
# 239  Economy 'strong' in election year\n\nUK busine...  business
# 252  Jobs growth still slow in the US\n\nThe US cre...  business
# 332  Troubled Marsh under SEC scrutiny\n\nThe US st...  business
# 355  S Korea spending boost to economy\n\nSouth Kor...  business
# 370  Singapore growth at 8.1% in 2004\n\nSingapore'...  business
# 98 duplicated rows

# %%
# Visualise the number of articles per category:
sns.countplot(data=articles, y="category", order=articles["category"].value_counts().index, palette="viridis")
plt.title("Number of Articles per Category")
plt.xlabel("# Articles")
plt.ylabel("Category")
plt.tight_layout()
plt.show()

# %%
# Define functions to count the number of words, sentences, and stop words for each row:
def count_words(text):
    if not isinstance(text, str):
        return 0 # Handle non-string values
    words = word_tokenize(text) # Convert text to a list of words
    return len(words) #return number of words

def count_sentences(text): # Repeat for sentences
    if not isinstance(text, str):
        return 0
    sentences = sent_tokenize(text)
    return len(sentences)

def count_stopwords(text): # Repeat for number of stop words
    if not isinstance(text, str): 
        return 0
    words = word_tokenize(text.lower()) 
    stopword_count = sum(1 for word in words if word in stopwords_list)
    return stopword_count

# Apply to each article
articles["num_words"] = articles["text"].apply(count_words).round(2)
articles["num_sentences"] = articles["text"].apply(count_sentences)
articles["num_stopwords"] = articles["text"].apply(count_stopwords)

# Calculate averages per category
averages_per_category = articles.groupby("category")[["num_sentences", "num_words", "num_stopwords"]].mean().reset_index().round(2)

# Rename columns
averages_per_category.rename(columns={
    "num_sentences": "Average Sentences",
    "num_words": "Average Words",
    "num_stopwords": "Average Stop Words"
}, inplace=True)

print("Average metrics per category:\n", averages_per_category)
# Out:
# Average metrics per category:
#          category  Average Sentences  Average Words  Average Stop Words
# 0       business              15.68         376.74              172.52
# 1  entertainment              16.49         382.28              179.57
# 2       politics              21.03         517.36              254.72
# 3          sport              17.16         382.39              190.38
# 4           tech              24.60         577.88              280.12

# %%
#Plot average sentences, words and stop words per category

plt.figure(figsize=(15, 6))

# Average Sentences
plt.subplot(1, 3, 1) 
sns.barplot(x="category", y="Average Sentences", data=averages_per_category, palette="viridis")
plt.title("Average Number of Sentences per Category")
plt.xlabel("Category")
plt.ylabel("Average Sentences")

# Average Words per Category
plt.subplot(1, 3, 2) 
sns.barplot(x="category", y="Average Words", data=averages_per_category, palette="magma")
plt.title("Average Number of Words per Category")
plt.xlabel("Category")
plt.ylabel("Average Words")

# Average Stop Words per Category
plt.subplot(1, 3, 3)
sns.barplot(x="category", y="Average Stop Words", data=averages_per_category, palette="cividis")
plt.title("Average Number of Stop Words per Category")
plt.xlabel("Category")
plt.ylabel("Average Stop Words")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Processing the data:
# Define a function to pre-process sentences using tokenisation, POS-tagging, lemmatisation, and removing stop-words, and a function to convert POS-tags to the format used by WNL:

# %%
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith("J"):
        return wordnet.ADJ
    elif treebank_tag.startswith("V"):
        return wordnet.VERB
    elif treebank_tag.startswith("N"):
        return wordnet.NOUN
    elif treebank_tag.startswith("R"):
        return wordnet.ADV
    else:
        return wordnet.NOUN 

def preprocess_sentence(input_text):
    tagged_text = []
    for word, tag in pos_tag(word_tokenize(input_text)):
        tagged_text.append((word, get_wordnet_pos(tag)))
        
    lemma_text = [WNL().lemmatize(word.lower(), pos=tag) for word, tag in tagged_text]
    processed_text = [word for word in lemma_text if word not in stopwords_list and not word.isdigit()]
    return processed_text

# %%
# Apply to the actricles in the dataset
articles["cleaned_text"] = articles["text"].apply(lambda x: " ".join(preprocess_sentence(x)))
articles.head()
# Out:
#                                                 text  category  num_words  \
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business        490
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business        433
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business        294
# 3  High fuel prices hit BA's profits\n\nBritish A...  business        472
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business        306
#
#    num_sentences  num_stopwords  \
# 0             20            229
# 1             15            194
# 2             12            133
# 3             19            201
# 4             12            132
#
#                                         cleaned_text
# 0  ad sale boost time warner profit quarterly pro...
# 1  dollar gain greenspan speech dollar hit high l...
# 2  yukos unit buyer face loan claim owner embattl...
# 3  high fuel price hit ba 's profit british airwa...
# 4  pernod takeover talk lift domecq share uk drin...

# %% [markdown]
# We can also use TextRank summarisation to simplify the articles. TextRank has been chosen as it balances a greater complexity than traditional summarisation against the much higher computational costs of abstract summarisation (and the risks associated with generative extraction by the latter).

# %%
text_rank_summarizer = TextRankSummarizer()
def textRank_summary(text, n=2):
    try:
        parser = PlaintextParser.from_string(text, Tokenizer("english"))
        summary = text_rank_summarizer(parser.document, sentences_count=n)
        return " ".join(str(sentence) for sentence in summary)
    except Exception as e:
        return ""

articles["textRank_summary"] = articles["text"].apply(textRank_summary)

articles.head()
# Out:
#                                                 text  category  num_words  \
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business        490
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business        433
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business        294
# 3  High fuel prices hit BA's profits\n\nBritish A...  business        472
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business        306
#
#    num_sentences  num_stopwords  \
# 0             20            229
# 1             15            194
# 2             12            133
# 3             19            201
# 4             12            132
#
#                                         cleaned_text  \
# 0  ad sale boost time warner profit quarterly pro...
# 1  dollar gain greenspan speech dollar hit high l...
# 2  yukos unit buyer face loan claim owner embattl...
# 3  high fuel price hit ba 's profit british airwa...
# 4  pernod takeover talk lift domecq share uk drin...
#
#                                     textRank_summary
# 0  But its film division saw profits slump 27% to...
# 1  In the meantime, the US Federal Reserve's deci...
# 2  The owners of embattled Russian oil giant Yuko...
# 3  Looking ahead to its full year results to Marc...
# 4  Shares in UK drinks and food firm Allied Domec...

# %% [markdown]
# ## Subject Classification
# As this data is unlabelled, unsupervised learning techniques will be used to estimate the topics within each broader category.
#
# Let's focus on just the sports articles:

# %%
sports_articles = articles[articles["category"] == "sport"].copy()

sports_articles.head()
# Out:
#                                                    text category  num_words  \
# 1313  Claxton hunting first major medal\n\nBritish h...    sport        235
# 1314  O'Sullivan could run in Worlds\n\nSonia O'Sull...    sport        158
# 1315  Greene sets sights on world title\n\nMaurice G...    sport        435
# 1316  IAAF launches fight against drugs\n\nThe IAAF ...    sport        226
# 1317  Dibaba breaks 5,000m world record\n\nEthiopia'...    sport        192
#
#       num_sentences  num_stopwords  \
# 1313             11            108
# 1314              7             64
# 1315             23            231
# 1316              9            120
# 1317             10             83
#
#                                            cleaned_text  \
# 1313  claxton hunt first major medal british hurdler...
# 1314  o'sullivan could run world sonia o'sullivan in...
# 1315  greene set sight world title maurice greene ai...
# 1316  iaaf launch fight drug iaaf athletics world go...
# 1317  dibaba break 5,000m world record ethiopia 's t...
#
#                                        textRank_summary
# 1313  Claxton has won the national 60m hurdles title...
# 1314  Athletics Ireland have hinted that the 35-year...
# 1315  "I believe that's what put me in lane seven in...
# 1316  It was also agreed that a programme to "de-mys...
# 1317  Ethiopia's Tirunesh Dibaba set a new world rec...

# %% [markdown]
# There are three broad approaches, topic modelling (such as NMF and LDA), rule-based labelling, or clustering.
# * Topic modelling aims to group the articles into similar 'hidden' topics, and returns key-words so they can be labelled.
# * Rule-based labelling searches for pre-defined labels, which is fast but requires effective and comprehensive domain knowledge.
# * Clustering vectorises each article and then groups based on similarity. This can be fast, but also less interpretable than others.
# * Alternatively:
#     * Zero-shot classification can also be used, which uses an already trained model to assign probabilistic labels to articles. However this can lack nuance as it is trained on external datasets, and can still be computationally expensive.
#     * If enough articles can be labelled, it may also be possible to use supervised machine learning

# %%
# Convert the articles into a 'bags-of-words', count frequencies, and translate to a vector
count_vector = CountVectorizer(min_df=0.05, max_df=0.9)
vectorised = count_vector.fit_transform(sports_articles["cleaned_text"])
features = count_vector.get_feature_names_out()

# %%
# Define a functon to print top phrases per identified topic
def get_top_keywords(model, feature_names, n_top_words=10):
    keywords = []
    for topic_idx, topic in enumerate(model.components_):
        top_features = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        keywords.append(top_features)
    return keywords

# %%
# Calculate optimal number of topics for LDA by plotting coherence score
texts = sports_articles["cleaned_text"].apply(lambda x: x.split()) # tokenise and split out words
dictionary = corpora.Dictionary(texts) # creates an ID'ed dictionary of the words
corpus = [dictionary.doc2bow(text) for text in texts] # Converts to a bag-of-words

coherence_values = []
topic_range = range(2, 15) # check for between 2 and 14 topics

for num_topics in topic_range: # train a model for each number of topics and extract coherence score
    model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, random_state=50)
    coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence="c_v")
    coherence_values.append(coherencemodel.get_coherence())

plt.plot(topic_range, coherence_values, marker="o")
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score (c_v)")
plt.title("LDA Coherence Score by Topic Number")
plt.grid(True)
plt.show()

# %%
# Perform LDA using 12 topics
lda_model = LatentDirichletAllocation(n_components=12, random_state=50)
lda_topics = lda_model.fit_transform(vectorised)
sports_articles["LDA_topic"] = lda_topics.argmax(axis=1) # Assign each articles to it's identified topic

# Extract and print top keywords per topic
lda_keywords = get_top_keywords(lda_model, features) 
for i, topic in enumerate(lda_keywords): 
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# Topic 0: england, robinson, rugby, six, game, nation, andy, sale, say, matt
# Topic 1: ireland, wale, game, france, half, win, england, italy, try, side
# Topic 2: set, win, match, play, break, game, say, final, first, beat
# Topic 3: referee, kick, ball, get, united, go, take, say, two, could
# Topic 4: minute, goal, half, penalty, score, second, lead, time, ball, first
# Topic 5: test, say, drug, ban, charge, take, also, miss, athens, year
# Topic 6: say, club, would, game, play, player, go, chelsea, league, liverpool
# Topic 7: world, win, year, second, race, title, final, time, champion, record
# Topic 8: player, say, play, england, rugby, injury, year, coach, cup, back
# Topic 9: new, zealand, tour, lion, match, australia, deal, first, team, leave
# Topic 10: open, win, year, say, play, round, first, australian, last, injury
# Topic 11: athletics, say, athlete, run, would, olympic, year, go, athens, medal

# %%
# label these topics
LDA_labels = {
    0 : "Rugby",
    1 : "Rugby",
    2 : "Tennis",
    3 : "Football",
    4 : "Football",
    5 : "Olympics/Athletics",
    6 : "Football",
    7 : "Olympics/Athletics",
    8 : "Rugby",
    9 : "Rugby",
    10 : "Golf",
    11 : "Olympics/Athletics"}

sports_articles["LDA_topic"] = sports_articles["LDA_topic"].map(LDA_labels)

# %%
# Calculate optimal n for NMF: 
recon_errors = []
topic_range = range(2, 15)

for k in topic_range: # Train an NMF model for between 2 and 14 topics
    model = NMF(n_components=k, random_state=50)
    W = model.fit_transform(vectorised)
    H = model.components_
    recon_error = model.reconstruction_err_
    recon_errors.append(recon_error)

plt.plot(topic_range, recon_errors, marker="o")
plt.xlabel("Number of Topics")
plt.ylabel("Reconstruction Error")
plt.title("NMF Reconstruction Error")
plt.grid(True)
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\decomposition\_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
#Perform NMF, looking for 6 topics (as the marginal gain starts to decrease at 6, and we want to avoid overfitting)
nmf_model = NMF(n_components=6, random_state=50)
nmf_topics = nmf_model.fit_transform(vectorised)
sports_articles["NMF_topic"] = nmf_topics.argmax(axis=1)

# Extract and print top keywords per topic
nmf_keywords = get_top_keywords(nmf_model, features)
for i, topic in enumerate(nmf_keywords):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# Topic 0: england, six, ireland, france, nation, play, robinson, game, say, coach
# Topic 1: say, would, club, liverpool, player, go, want, think, get, make
# Topic 2: year, win, world, second, champion, title, time, say, final, best
# Topic 3: new, zealand, wale, game, win, first, rugby, team, tour, side
# Topic 4: game, point, set, break, serve, hold, first, match, go, two
# Topic 5: minute, half, try, penalty, ireland, goal, ball, second, lead, time

# %%
# Assign estimated labels
NMF_labels = {
    0 : "Rugby",
    1 : "Football",
    2 : "Olympics/Athletics",
    3 : "Rugby",
    4 : "Tennis",
    5 : "Rugby"}

sports_articles["NMF_topic"] = sports_articles["NMF_topic"].map(NMF_labels)

# %%
sports_articles.head()
# Out:
#                                                    text category  num_words  \
# 1313  Claxton hunting first major medal\n\nBritish h...    sport        235
# 1314  O'Sullivan could run in Worlds\n\nSonia O'Sull...    sport        158
# 1315  Greene sets sights on world title\n\nMaurice G...    sport        435
# 1316  IAAF launches fight against drugs\n\nThe IAAF ...    sport        226
# 1317  Dibaba breaks 5,000m world record\n\nEthiopia'...    sport        192
#
#       num_sentences  num_stopwords  \
# 1313             11            108
# 1314              7             64
# 1315             23            231
# 1316              9            120
# 1317             10             83
#
#                                            cleaned_text  \
# 1313  claxton hunt first major medal british hurdler...
# 1314  o'sullivan could run world sonia o'sullivan in...
# 1315  greene set sight world title maurice greene ai...
# 1316  iaaf launch fight drug iaaf athletics world go...
# 1317  dibaba break 5,000m world record ethiopia 's t...
#
#                                        textRank_summary           LDA_topic  \
# 1313  Claxton has won the national 60m hurdles title...  Olympics/Athletics
# 1314  Athletics Ireland have hinted that the 35-year...  Olympics/Athletics
# 1315  "I believe that's what put me in lane seven in...  Olympics/Athletics
# 1316  It was also agreed that a programme to "de-mys...  Olympics/Athletics
# 1317  Ethiopia's Tirunesh Dibaba set a new world rec...  Olympics/Athletics
#
#                NMF_topic
# 1313  Olympics/Athletics
# 1314  Olympics/Athletics
# 1315  Olympics/Athletics
# 1316            Football
# 1317  Olympics/Athletics

# %%
# Rule based matching to identify keywords and evaluate:
nlp = spacy.load("en_core_web_sm")

# Define sports keywords to look for
sports = ["cricket", "football", "rugby", "tennis", "nba", "formula one", "f1", "olympics", "athletics", "golf", "boxing", "basketball", "darts"]
patterns = [nlp.make_doc(sport) for sport in sports]
matcher = PhraseMatcher(nlp.vocab)
matcher.add("SPORTS", patterns)

def detect_sport(text):
    doc = nlp(text.lower())
    matches = matcher(doc)
    matched = list(set([doc[start:end].text for _, start, end in matches]))
    return matched[0] if matched else "unknown"

# Apply keyword-categorisation where possible
sports_articles["rbm_sport"] = sports_articles["text"].apply(detect_sport)

# %%
# Compare NMF topics to matched key-words
pd.crosstab(sports_articles["NMF_topic"], sports_articles["rbm_sport"])
# Out:
# rbm_sport           athletics  basketball  boxing  cricket  football  golf  \
# NMF_topic
# Football                    3           0       0        0        54     0
# Olympics/Athletics         14           0       0        0         5     0
# Rugby                       0           1       0        2        17     1
# Tennis                      0           1       1        0         2     0
#
# rbm_sport           olympics  rugby  tennis  unknown
# NMF_topic
# Football                  12     14      13       89
# Olympics/Athletics        23      1      17       67
# Rugby                      1     43       0       83
# Tennis                     0      1       8       32

# %%
# Compare LDA topics to matched key-words
pd.crosstab(sports_articles["LDA_topic"], sports_articles["rbm_sport"])
# Out:
# rbm_sport           athletics  basketball  boxing  cricket  football  golf  \
# LDA_topic
# Football                    0           0       1        0        61     0
# Golf                        0           0       0        0         2     0
# Olympics/Athletics         17           0       0        0         0     0
# Rugby                       0           1       0        2        14     1
# Tennis                      0           1       0        0         1     0
#
# rbm_sport           olympics  rugby  tennis  unknown
# LDA_topic
# Football                   1      6       6      115
# Golf                       1      1      13       18
# Olympics/Athletics        33      1       6       43
# Rugby                      1     50       2       66
# Tennis                     0      1      11       29

# %%
# The "golf" topic looks like it often mentions tennis, so we can re-assign
sports_articles["LDA_topic"] = sports_articles["LDA_topic"].replace("Golf", "Tennis")
pd.crosstab(sports_articles["LDA_topic"], sports_articles["rbm_sport"])
# Out:
# rbm_sport           athletics  basketball  boxing  cricket  football  golf  \
# LDA_topic
# Football                    0           0       1        0        61     0
# Olympics/Athletics         17           0       0        0         0     0
# Rugby                       0           1       0        2        14     1
# Tennis                      0           1       0        0         3     0
#
# rbm_sport           olympics  rugby  tennis  unknown
# LDA_topic
# Football                   1      6       6      115
# Olympics/Athletics        33      1       6       43
# Rugby                      1     50       2       66
# Tennis                     1      2      24       47

# %% [markdown]
# Of the articles with a keyword found, assigned topics had an accuracy of:
# * Football: NMF - 57.3%, LDA - 81.3%
# * Olympics/Athletics: NMF - 60.0%, LDA - 84.2%
# * Rugby: NMF - 66.2%, LDA - 69.0%
# * Tennis: NMF - 69.2%, LDA - 80.6%
#
# LDA appears to have been more successful at grouping topics, although a significant number did not have a defined key-word to enable comparison.
#
# We can use TSNE to dimension reduce and visualise these groups in 2-dimensions:

# %%
tsne_model = TSNE(n_components=2, perplexity=30, random_state=50, n_iter=1000)
tsne_values = tsne_model.fit_transform(lda_topics)

sports_articles["tsne_x"] = tsne_values[:, 0]
sports_articles["tsne_y"] = tsne_values[:, 1]

# Plot using seaborn
plt.figure(figsize=(10, 7))
sns.scatterplot(data=sports_articles, x="tsne_x", y="tsne_y", hue="LDA_topic", palette="tab10", s=60)

plt.title("t-SNE Visualization of LDA Topics")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.legend(title="Topic", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# There is clear clustering within the data, which align closely with topics assigned by LDA. There are some 'strays' however these do not necessarily represent inaccuracies, as articles across different sports may contain similarities.

# %%
# Repeat for Entertainment articles
entertainment_articles = articles[articles["category"] == "entertainment"].copy()

# Vectorise text
count_vector = CountVectorizer(min_df=0.05, max_df=0.9)
vectorised = count_vector.fit_transform(entertainment_articles["cleaned_text"])
features = count_vector.get_feature_names_out()

# Calculate ideal number of topics for LDA (same method as before)
texts = entertainment_articles["cleaned_text"].apply(lambda x: x.split())
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

coherence_values = []
topic_range = range(2, 15)

for num_topics in topic_range:
    model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, passes=10, random_state=50)
    coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence="c_v")
    coherence_values.append(coherencemodel.get_coherence())

plt.plot(topic_range, coherence_values, marker="o")
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score (c_v)")
plt.title("LDA Coherence Score by Topic Number (Entertainment)")
plt.grid(True)
plt.show()

# And ideal number of topics for NMF
recon_errors = []
for k in topic_range:
    model = NMF(n_components=k, random_state=50)
    W = model.fit_transform(vectorised)
    H = model.components_
    recon_errors.append(model.reconstruction_err_)

plt.plot(topic_range, recon_errors, marker="o")
plt.xlabel("Number of Topics")
plt.ylabel("Reconstruction Error")
plt.title("NMF Reconstruction Error (Entertainment)")
plt.grid(True)
plt.show()

# %%
# Perform LDA (same method as before)
entertainment_articles = articles[articles["category"] == "entertainment"].copy()

count_vector = CountVectorizer(min_df=0.05, max_df=0.9)
vectorised = count_vector.fit_transform(entertainment_articles["cleaned_text"])
features = count_vector.get_feature_names_out()

lda_model = LatentDirichletAllocation(n_components=8, random_state=50)
lda_topics = lda_model.fit_transform(vectorised)
entertainment_articles["LDA_topic"] = lda_topics.argmax(axis=1)

lda_keywords = get_top_keywords(lda_model, features)
for i, topic in enumerate(lda_keywords):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# Topic 0: say, star, film, mr, year, make, also, tell, new, would
# Topic 1: music, say, band, album, make, like, year, get, people, would
# Topic 2: number, top, chart, one, year, single, album, take, release, box
# Topic 3: best, award, film, win, oscar, actor, actress, nomination, director, star
# Topic 4: film, festival, year, director, award, include, star, actor, book, role
# Topic 5: song, year, last, vote, show, best, celebrity, say, win, brother
# Topic 6: show, say, tv, bbc, series, new, one, people, programme, also
# Topic 7: band, sale, music, year, say, include, singer, concert, sell, fan

# %%
# Assign estimated labels
LDA_labels = {
    0 : "Film",
    1 : "Music",
    2 : "Music",
    3 : "Film",
    4 : "Film",
    5 : "Music",
    6 : "TV",
    7 : "Music"}

entertainment_articles["LDA_topic"] = entertainment_articles["LDA_topic"].map(LDA_labels)

# %%
#Perform NMF, looking for 8 topics:
nmf_model = NMF(n_components=8, random_state=50)
nmf_topics = nmf_model.fit_transform(vectorised)
entertainment_articles["NMF_topic"] = nmf_topics.argmax(axis=1)

nmf_keywords = get_top_keywords(nmf_model, features)
for i, topic in enumerate(nmf_keywords):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# Topic 0: song, best, year, music, last, think, award, vote, win, good
# Topic 1: film, festival, year, star, make, movie, oscar, director, award, role
# Topic 2: music, black, people, stone, make, good, term, win, award, think
# Topic 3: best, award, win, also, prize, name, star, nomination, comedy, ceremony
# Topic 4: number, chart, band, top, album, one, single, uk, new, release
# Topic 5: show, make, tv, see, would, could, big, child, like, new
# Topic 6: say, mr, year, star, show, also, add, work, tell, get
# Topic 7: film, actor, director, actress, jamie, aviator, win, scorsese, best, oscar

# %%
# Assign estimated labels
NMF_labels = {
    0 : "Music",
    1 : "Film",
    2 : "Music",
    3 : "Film",
    4 : "Music",
    5 : "TV",
    6 : "TV",
    7 : "Film"}

entertainment_articles["NMF_topic"] = entertainment_articles["NMF_topic"].map(NMF_labels)

# %%
# Perform Rule-based matching to assess topic labels

# Define entertainment-related keywords
entertainment_keywords = [
    "music", "movie", "film", "tv", "television", "cinema", "oscars", "emmys",
    "grammys", "broadway", "theatre", "concert", "album", "song", "book", "author"]


patterns = [nlp.make_doc(keyword) for keyword in entertainment_keywords]
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
matcher.add("ENTERTAINMENT", patterns)

# Detect keywords in text:
def detect_entertainment_topic(text):
    doc = nlp(text.lower())
    matches = matcher(doc)
    matched_terms = list(set([doc[start:end].text for _, start, end in matches]))
    return matched_terms[0] if matched_terms else "unknown"

entertainment_articles["rbm_topic"] = entertainment_articles["text"].apply(detect_entertainment_topic)

# %%
# Compare NMF and LDA topics to keywords:
pd.crosstab(entertainment_articles["NMF_topic"], entertainment_articles["rbm_topic"])
# Out:
# rbm_topic  album  author  book  broadway  cinema  concert  film  grammys  \
# NMF_topic
# Film           6       3     2         1       3        0    90        2
# Music         33       0     2         0       0        3    14        5
# TV            13       5     5         3       2        1    33        0
#
# rbm_topic  movie  music  oscars  song  television  theatre  tv  unknown
# NMF_topic
# Film           9      1       0     0           2        1   7        0
# Music          3     15       0     4           1        1   0        4
# TV             7     28       1     3          11        1  21       23

# %%
pd.crosstab(entertainment_articles["LDA_topic"], entertainment_articles["rbm_topic"])
# Out:
# rbm_topic  album  author  book  broadway  cinema  concert  film  grammys  \
# LDA_topic
# Film          14       8     5         3       4        0   106        2
# Music         38       0     2         0       0        3    23        5
# TV             0       0     2         1       1        1     8        0
#
# rbm_topic  movie  music  oscars  song  television  theatre  tv  unknown
# LDA_topic
# Film          14     12       1     0           3        2  14        6
# Music          4     25       0     4           7        1   4       17
# TV             1      7       0     3           4        0  10        4

# %%
# Visualise using TNSE
tsne_model = TSNE(n_components=2, perplexity=30, random_state=50, n_iter=1000)
tsne_values = tsne_model.fit_transform(lda_topics)

entertainment_articles["tsne_x"] = tsne_values[:, 0]
entertainment_articles["tsne_y"] = tsne_values[:, 1]

# Plot using seaborn
plt.figure(figsize=(10, 7))
sns.scatterplot(data=entertainment_articles, x="tsne_x", y="tsne_y", hue="LDA_topic", palette="tab10", s=60)

plt.title("t-SNE Visualization of LDA Topics")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.legend(title="Topic", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Repeat for business articles:
business_articles = articles[articles["category"] == "business"].copy()

count_vector = CountVectorizer(min_df=0.05, max_df=0.9)
vectorised = count_vector.fit_transform(business_articles["cleaned_text"])
features = count_vector.get_feature_names_out()

texts = business_articles["cleaned_text"].apply(lambda x: x.split())
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Find optimal number of topics for LDA
coherence_values = []
topic_range = range(2, 15)

for num_topics in topic_range:
    model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, passes=10, random_state=50)
    coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence="c_v")
    coherence_values.append(coherencemodel.get_coherence())

plt.plot(topic_range, coherence_values, marker="o")
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score (c_v)")
plt.title("LDA Coherence Score by Topic Number (Business)")
plt.grid(True)
plt.show()

# Find optimal number of topics for NMF
recon_errors = []
for k in topic_range:
    model = NMF(n_components=k, random_state=50)
    W = model.fit_transform(vectorised)
    H = model.components_
    recon_errors.append(model.reconstruction_err_)

plt.plot(topic_range, recon_errors, marker="o")
plt.xlabel("Number of Topics")
plt.ylabel("Reconstruction Error")
plt.title("NMF Reconstruction Error (Business)")
plt.grid(True)
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\decomposition\_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\decomposition\_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\decomposition\_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
# Perform LDA:
count_vector = CountVectorizer(min_df=0.05, max_df=0.9)
vectorised = count_vector.fit_transform(business_articles["cleaned_text"])
features = count_vector.get_feature_names_out()

lda_model = LatentDirichletAllocation(n_components=8, random_state=50)
lda_topics = lda_model.fit_transform(vectorised)
business_articles["LDA_topic"] = lda_topics.argmax(axis=1)

lda_keywords = get_top_keywords(lda_model, features)
for i, topic in enumerate(lda_keywords):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# Topic 0: sale, share, company, firm, market, india, new, analyst, uk, stock
# Topic 1: rise, rate, year, growth, economy, price, figure, month, market, bank
# Topic 2: dollar, euro, airline, year, deficit, budget, cost, fuel, air, currency
# Topic 3: bank, mr, government, state, would, united, foreign, investment, tell, rule
# Topic 4: year, profit, sale, car, share, firm, company, rise, buy, last
# Topic 5: yukos, oil, russian, court, company, russia, china, firm, tax, gas
# Topic 6: country, year, economic, world, people, government, economy, 000, job, also
# Topic 7: mr, company, firm, bid, share, offer, executive, would, chief, shareholder

# %%
# Assign estimated labels
LDA_labels = {
    0 : "Stock Market",
    1 : "Economics",
    2 : "Company News",
    3 : "Economics",
    4 : "Company News",
    5 : "Company News",
    6 : "Economics",
    7 : "Mergers & Acquisitions"}

business_articles["LDA_topic"] = business_articles["LDA_topic"].map(LDA_labels)

# %%
#Perform NMF, looking for 7 topics:
nmf_model = NMF(n_components=7, random_state=50)
nmf_topics = nmf_model.fit_transform(vectorised)
business_articles["NMF_topic"] = nmf_topics.argmax(axis=1)

nmf_keywords = get_top_keywords(nmf_model, features)
for i, topic in enumerate(nmf_keywords):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# Topic 0: sale, year, profit, car, rise, expect, last, euro, 000, december
# Topic 1: share, company, firm, market, would, stock, offer, make, deal, exchange
# Topic 2: yukos, oil, russian, company, court, tax, russia, firm, bankruptcy, state
# Topic 3: year, country, economic, economy, government, growth, world, budget, also, deficit
# Topic 4: mr, united, fraud, tell, chief, proposal, company, year, former, new
# Topic 5: bank, china, standard, big, south, one, loan, two, make, new
# Topic 6: price, rise, rate, market, growth, month, year, economy, fall, figure

# %%
# Assign estimated labels
NMF_labels = {
    0 : "Company News",
    1 : "Stock Market",
    2 : "Company News",
    3 : "Economics",
    4 : "Company News",
    5 : "Company News",
    6 : "Stock Market"}

business_articles["NMF_topic"] = business_articles["NMF_topic"].map(LDA_labels)

# %%
# Define business keywords
business_keywords = ["economy", "finance", "stock market", "stocks", "shares", "merger", "acquistion", "company", "market", "gdp"]

patterns = [nlp.make_doc(keyword) for keyword in business_keywords]
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
matcher.add("BUSINESS", patterns)

# Detect keywords:
def detect_business_topic(text):
    doc = nlp(text.lower())
    matches = matcher(doc)
    matched_terms = list(set([doc[start:end].text for _, start, end in matches]))
    return matched_terms[0] if matched_terms else "unknown"

business_articles["rbm_topic"] = business_articles["text"].apply(detect_business_topic)

# %%
pd.crosstab(business_articles["NMF_topic"], business_articles["rbm_topic"])
# Out:
# rbm_topic     company  economy  finance  gdp  market  merger  shares  \
# NMF_topic
# Company News       51       17        1    2      33      10       7
# Economics          35       98       11   19      85      13       4
# Stock Market       17        4        0    0      16       0       1
#
# rbm_topic     stock market  stocks  unknown
# NMF_topic
# Company News             1       1       19
# Economics                2       4       49
# Stock Market             0       0        3

# %%
pd.crosstab(business_articles["LDA_topic"], business_articles["rbm_topic"])
# Out:
# rbm_topic               company  economy  finance  gdp  market  merger  \
# LDA_topic
# Company News                 40       27        5    2      48       3
# Economics                    23       86        4   19      33       3
# Mergers & Acquisitions       26        1        2    0      28      15
# Stock Market                 14        5        1    0      25       2
#
# rbm_topic               shares  stock market  stocks  unknown
# LDA_topic
# Company News                 6             0       0       14
# Economics                    2             1       4       45
# Mergers & Acquisitions       4             2       1        8
# Stock Market                 0             0       0        4

# %%
# Visualise using TNSE
tsne_model = TSNE(n_components=2, perplexity=30, random_state=50, n_iter=1000)
tsne_values = tsne_model.fit_transform(lda_topics)

business_articles["tsne_x"] = tsne_values[:, 0]
business_articles["tsne_y"] = tsne_values[:, 1]

# Plot using seaborn
plt.figure(figsize=(10, 7))
sns.scatterplot(data=business_articles, x="tsne_x", y="tsne_y", hue="LDA_topic", palette="tab10", s=60)

plt.title("t-SNE Visualization of LDA Topics")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.legend(title="Topic", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Desirable
#
# * Extract summaries of anything that took place or is/was scheduled to take place in April.

# %%
# Extract articles with a mention of April
april_articles = articles[articles["text"].str.contains("April|Apr", case=False, na=False)]
april_articles.head()
# Out:
#                                                  text  category  num_words  \
# 12  Peugeot deal boosts Mitsubishi\n\nStruggling J...  business        336
# 33  Rover deal 'may cost 2,000 jobs'\n\nSome 2,000...  business        349
# 70  Japan turns to beer alternatives\n\nJapanese b...  business        251
# 79  Argentina, Venezuela in oil deal\n\nArgentina ...  business        217
# 97  IMF 'cuts' German growth estimate\n\nThe Inter...  business        253
#
#     num_sentences  num_stopwords  \
# 12             14            144
# 33             14            159
# 70             10            118
# 79             11             81
# 97             10            119
#
#                                          cleaned_text  \
# 12  peugeot deal boost mitsubishi struggle japanes...
# 33  rover deal 'may cost 2,000 jobs' 2,000 job mg ...
# 70  japan turn beer alternative japanese brewer in...
# 79  argentina venezuela oil deal argentina venezue...
# 97  imf 'cuts german growth estimate international...
#
#                                      textRank_summary
# 12  Falling sales have left Mitsubishi Motors with...
# 33  Shanghai Automotive Industry Corp plans to shi...
# 70  Now, according to Asahi Breweries, the market ...
# 79  Argentina and Venezuela have extended a food-f...
# 97  The IMF will also reduce its growth estimate f...

# %%
april_articles["textRank_summary"]
# Out:
# 12      Falling sales have left Mitsubishi Motors with...
# 33      Shanghai Automotive Industry Corp plans to shi...
# 70      Now, according to Asahi Breweries, the market ...
# 79      Argentina and Venezuela have extended a food-f...
# 97      The IMF will also reduce its growth estimate f...
#                               ...
# 1968    "We looked at more of the independent musician...
# 1997    "We are proud of it because it has the sound q...
# 2007    But she did not, because having fast, always o...
# 2087    The rest of the world was also falling in love...
# 2098    Ofcom wants to ensure that the arrival of UWB-...
# Name: textRank_summary, Length: 124, dtype: object

# %% [markdown]
# * Identify documents and extract the named entities for media personalities, clearly identifying their jobs (e.g. Politicians, TV/Film Personalities, Musicians)

# %%
# Utilise rule-based matching to extract names and jobs:

# Load spaCy model
nlp = spacy.load("en_core_web_trf")

# Define jobs:
media_jobs = [
    "journalist", "reporter", "presenter", "anchor", "correspondent", "editor",
    "newsreader", "host", "commentator", "columnist", "broadcaster", "media personality", 
    "policitian", "mp", "musician", "guitarist", "drummer", "singer", "director", "actor", 
    "actress", "director", "dj", "producer", "pm", "prime minister"]

# Regex to match job titles
job_title_pattern = re.compile(r"\b(" + "|".join(media_jobs) + r")s?\b", re.IGNORECASE)

# Function to extract name and job title from a text
def extract_media_personalities(text):
    doc = nlp(text)
    results = []

    for ent in doc.ents:
        if ent.label_ == "PERSON":
            name = ent.text.strip()
            sentence = ent.sent.text  # Get the full sentence containing the name
            job_matches = job_title_pattern.findall(sentence)
            for job in job_matches:
                results.append((name, job.lower()))
    return results

# Extract names and jobs from each article
all_personalities = []

for article in articles["text"]:
    results = extract_media_personalities(article)
    all_personalities.extend(results)

# Remove duplicates:
all_personalities = set(all_personalities)

# Print results
for name, job in all_personalities:
    print(f"{name}: {job}")
# Out:
# Jonathan Ross: presenter
# Martin Bashir: reporter
# Stephen Fry: host
# Tan: director
# Michel Gondry: director
# Philip Mawer: mp
# Stephen Douglas: pm
# Philippe Torreton: actor
# Cable: mp
# Dizzee Rascal: singer
# Armando Falcon: director
# Alison Howe: producer
# Martin Scorsese: actor
# Tim McGraw: singer
# Katherine Hepburn: actress
# Depp: director
# Butler: mp
# Tautou: director
# Lisa I'Anson: dj
# Boy George: singer
# Roberts: actress
# Roger Clarke: actress
# Martin Henderson: actor
# Matthew Bourne: producer
# James Dean Bradfield: drummer
# Gary Lightbody: singer
# Nathan Lane: director
# Ariel Sharon: prime minister
# Alicia Keys: actor
# Alastair Campbell: prime minister
# Pierce Brosnan: producer
# Robert Light: mp
# Foxx: singer
# Dams: director
# Conleth Hill: producer
# Roger DeBris: director
# Eric Burdon: commentator
# King: host
# John Holmes: singer
# Billy: actor
# James Roper: director
# Charles Gant: actor
# Ron Howard: actress
# Freddie Mercury's: singer
# Philip Snalune: director
# Connick: actor
# Renner: director
# Edna Mode: actor
# Delta Goodrem: singer
# Franz Ferdinand: dj
# Howard: prime minister
# Buhecha: director
# Charles Clarke: mp
# Samuel L Jackson: actor
# Howard Hughes: actor
# John Peel: dj
# Andre 3000: dj
# Tim Mazanec: director
# Clint Eastwood: actress
# Scott: actor
# Ashanti: singer
# Stern: host
# James Cameron: director
# Tim Dams: actor
# Brown: editor
# Luc Bondy: director
# Tony Blair: mp
# Doug: mp
# Matt Bellamy: singer
# Brando: actor
# Patrick Walden: singer
# Zhang Yimou: director
# Dan Jolin: editor
# Malcolm X: director
# Roger Moore: actor
# Robert Tapsfield: director
# MacKenzie: prime minister
# Jimmy Page: drummer
# Oona King: mp
# William Makepeace Thackeray's: director
# Cheadle: actress
# Michael Maloney: actor
# Conor McNicholas: dj
# Im Kwon-Taek: director
# Pawel Pawlikowski: director
# Sara Forestier: actress
# Rachel Harvey: correspondent
# Charlie Parker: musician
# Brown: prime minister
# Kefa Ssempgani: mp
# Clint Wheelock: director
# Tony Hunter: director
# Tuffy: broadcaster
# Jeunet: actress
# Carson: host
# Adams: actor
# Patricia: actor
# James Wareham: director
# Carol Walker: correspondent
# Gordon Lishman: director
# Robert Boyle: director
# Henry Fonda: singer
# Stephen Pound: mp
# Margaret Moran MP: journalist
# Connick: producer
# Phillips: mp
# Thomas Ades: actor
# Charlie Whelan: prime minister
# Clare Higgins: producer
# Polly Adams: actor
# Skarsgard: director
# Rodgers: singer
# E Nesbit: actor
# Adam Curry: host
# Sharon Tate: actress
# Ron Howard: actor
# Joss Stone: singer
# Michael Howard: director
# Bill Conti's: director
# Marlon Brando: actor
# Owen: actor
# Gram Parsons: producer
# Gretchen Wilson: singer
# Gary Oldman: actor
# Damien Rice: singer
# Paul Saffo: director
# Tess Daly: host
# O'Casey: actor
# Tony Blair: pm
# Cate Blanchett: actor
# Clint Eastwood: actor
# Walliams: actor
# Andy Stephens: producer
# Alice Marchak: actor
# Bruce Springsteen: singer
# Ras Kwame: dj
# Claudia Schiffer: actress
# , Ken Macdonald QC: director
# Stan Lee: producer
# King: broadcaster
# Lionel Richie: producer
# Eric Joyce: mp
# Gordon Brown's: prime minister
# Davis: actor
# Michael Mann: director
# Lorraine Kelly: host
# Barbara Windsor: actress
# Tom Meighan: singer
# Jack Straw: prime minister
# Paul Burrell: host
# Kennedy: prime minister
# Clarke: mp
# Morgan Spurlock: director
# Luciano Orquera: host
# Mates: prime minister
# Quentin Tarantino: reporter
# Ray Charles: actor
# Gold: director
# Nick McCarthy: guitarist
# Andrew Burn: director
# John Wyver: producer
# Naris Chaiyasoot: director
# Helmut Schneider: director
# Devine: host
# Marcia Cross: actress
# Teddy Taylor: mp
# Liam Neeson: actress
# Tony Jordan: reporter
# Virginia Madsen: actor
# DiCaprio: director
# Amitabh Bachchan: actress
# Andrew Tyrie: mp
# Steven Gaydos: actor
# David Blunkett's: prime minister
# Jessica Taylor: presenter
# Liam Gallagher: singer
# Bond: actor
# Claude Errera: editor
# Sean Moore: guitarist
# Wayne Rooney: host
# Mick Potter: actor
# Richard McCourt: presenter
# Neil Hammerton: director
# Kleinberg: journalist
# Gerhard Schroeder: prime minister
# Robbie Stamp: producer
# Bush: prime minister
# Joe Jordan: director
# Richard Dodd: director
# Sidney Skolsky: columnist
# Nicky Wire: singer
# Negar Khan: actress
# Linda Thomsen: director
# Gerhard Florin: director
# Keanu Reeves: actor
# Chris Latham: host
# Mary Poppins: actress
# Joni Lovenduski: journalist
# Shauna Perry: producer
# Jeff Robinov: producer
# Swift: dj
# Tessa Jowell: prime minister
# Jacques Santini: director
# Tony Blair: reporter
# Alan Bennett: actor
# Alexander Payne: director
# Mike Read: dj
# Merrin: producer
# Bob Murray: broadcaster
# Bertie Ahern: prime minister
# Davis: producer
# Johnny Carson: presenter
# Shane Meadows: director
# Annette Bening: actress
# Anil Aggarwal: director
# Kenzie: actor
# Damian Hockney: host
# Nicholas Hytner: actor
# Rory O' Neill: editor
# Emmanuelle Devos: actress
# Lembit Opik: mp
# Hosni Mubarak: prime minister
# Steven Kull: director
# Attallah Shabazz: director
# Hill: director
# Greg Rusedski: host
# King: director
# Susan: director
# Charles: actor
# Evans: director
# Matthew Vaughn: director
# Oday Rasheed: director
# Elvis Presley: commentator
# Thomas Murphy: director
# the Director of Public Prosecutions: director
# Phil Laven: director
# Bond: producer
# Mick Potter: producer
# Trevor Nelson: dj
# John Frankenheimer: director
# Alexander McQueen: reporter
# Greg Dyke: director
# Alan Wass: singer
# Steven Soderbergh: director
# John Stevens: prime minister
# Schrader: producer
# Steve Morgan: prime minister
# Danny Fiszman: director
# Wim Kok: prime minister
# Hugh Laurie: host
# Nicholas: mp
# Ben Stiller: actor
# Ellen Degeneres: singer
# Michael Howard: mp
# Zhang Hemin: director
# Miranda Richardson: host
# Melcher: producer
# Fearne Cotton: host
# Alan Bennett: producer
# Katherine Hepburn: columnist
# Proof: dj
# Zoe Ball: dj
# Jonny Quinn: singer
# Jeremy Edwards: singer
# Reza Moghadam: director
# Southan Morris: producer
# George Clooney: actor
# Lee: director
# Nicholas Hytner: producer
# Ana Matronic: singer
# Margherita Taylor: dj
# Leo: prime minister
# Paul Sturrock: director
# Major: prime minister
# Taran Adarsh: editor
# Brad Bird: director
# Peter Lorimer: director
# Audrey Tautou: actress
# Kevin Hawkins: director
# Jerry Scoggins: singer
# Harlin: director
# Dan Peppe: presenter
# Jonathan Sayeed: mp
# Giles Cadle: actor
# Mark Robertson: editor
# Goodridge: director
# Bebo Valdes: singer
# Douglas Hodge: actor
# Jolin: actor
# Mary Madden: musician
# Deeley: host
# Sandra Bullock: actress
# Christopher Leslie: mp
# Alfonso Cuaron: director
# Harry: mp
# Simon Gardner: editor
# Tony Lloyd: mp
# Marc Anthony: singer
# Diana Rigg: actress
# Sheppey: prime minister
# Hugo Lueders: director
# Clarke: correspondent
# Siouxsie Sioux: singer
# Jana Bennett: director
# Joanne Harris: actor
# Sam Younger: mp
# Nicole: reporter
# Mark Oaten: mp
# Velimir Zajec: director
# David Blunkett: correspondent
# Nathan Lane: actor
# Milburn: broadcaster
# Jamelia: singer
# Ray: actress
# Lammy: mp
# William Shakespeare: actor
# Charles: commentator
# Dams: actor
# Chester Bennington: singer
# Tom Goldstein: journalist
# Dave Stewart: actor
# Anurag Kashyap: director
# Wong Kar-Wai: director
# Nogar: producer
# Roger Cumming: director
# Dave Grohl: drummer
# John Sergeant: editor
# Liam Fox: prime minister
# Burt Reynolds: actor
# Giles Cadle: producer
# Esther Rantzen: host
# Sandy Powell: director
# Philip Yea: director
# Dominick Chilcott: director
# Mamas: producer
# Chris Weitz: director
# Aamir Khan: actor
# John Peel: host
# Barley: dj
# Flicker: singer
# Amma Asante: actress
# Dustin Hoffman: actress
# John Lydon: actress
# Paul Smernicki: singer
# King: mp
# Michael Howard's: prime minister
# Jane Russell: actress
# Guido Gybels: director
# Ambrose Bierce: actor
# Pam Ferris: actress
# Bush: presenter
# Younger: mp
# Kisrty Williams: mp
# Vinod Pande: director
# Helen Sudell: editor
# Diana Rigg: actor
# Jonathan Maitland: presenter
# Akira Hurosawa: director
# Sergio Pizzorno: guitarist
# Gallagher: drummer
# Green Day: presenter
# Brian McBride: director
# Nathan Lane: producer
# Adrian Hosford: director
# Samuel Barnett: actress
# Charles Saumarez Smith: director
# Llwyd: mp
# Sheila Ferguson: singer
# Kate Winslet: actress
# William Shakespeare: producer
# Harold Wilson: prime minister
# Jason Bateman: actor
# Andrew Gilligan: director
# Guy Sebastian: singer
# Benazir Bhutto: prime minister
# Patrick Bartlett: correspondent
# Danniella Westbrook: singer
# Jonathan Pryce: actor
# Pedro Almodovar: director
# No ID: producer
# Helena Bonham-Carter: director
# Hilary Benn: prime minister
# James Stewart: producer
# Lisa Kudrow: actress
# Paul Simon: host
# Chris Evans: broadcaster
# Bob Hoskins: actor
# Rock: producer
# Clive Owen: actor
# Glazer: director
# Ricky Gervais: actor
# Mario Paniccia: director
# Sharon: prime minister
# Abdellatif Kechiche: director
# James Bond: director
# Scorsese: director
# Charles Aznavour: singer
# Eastwood: director
# Santini: director
# Bill Clinton: singer
# Paul Flynn: mp
# Edgar Allan Poe: actor
# John Bourn: prime minister
# Dan Gillmor: journalist
# Mohd-Saaid: director
# Doherty: guitarist
# Aamir Khan: producer
# Kevin Spacey: singer
# Alexander Payne: actress
# Stevie Wonder: singer
# Jean-Pierre Jeunet: director
# Lemar: singer
# Queen Latifah: actress
# Blunkett: prime minister
# Morrissey: singer
# Jamelia: host
# Gordon Brown: prime minister
# Jean Corston: mp
# Michael Stephenson: director
# Scoggins: musician
# Brian Harvey: singer
# Humphrey Bogart: actor
# Nair: director
# Will Smith: actor
# Marc Samuelson: producer
# John Coltrane: musician
# Ras Kwame: host
# Colin Salmon: actor
# Roger Taylor: guitarist
# Richard Attenborough: actress
# Charles Kennedy: prime minister
# Hilary Swank: singer
# Terry Palmer: director
# Anna Keaveney: actress
# Tony Macklin: director
# Tim Burton: director
# Hari Kunzru: director
# West: actor
# Lisa Kudrow: reporter
# Kanye West: producer
# Tim Kash: producer
# Sean Moore: singer
# Gavyn Davies: director
# Pan Yue: director
# Tim Healy: actor
# Phil Spector: actress
# Lehmann: host
# Gordon Macklin: director
# Hanks: actress
# McConnell: reporter
# DiCaprio: actor
# Jamie Graham: actor
# Leigh: actress
# Jerry Lee Lewis: musician
# Tony Lavender: director
# Natalie Portman: actress
# Swank: director
# Skarsgard: producer
# Nicki Chapman: editor
# Graham Henry: prime minister
# Victoria Hamilton: director
# David Felgate: director
# Jamie Cullum: singer
# Pele: actor
# Connors: director
# Stephen Fry: actor
# Thomas Dawson: director
# James Dean Bradfield: guitarist
# Fox: prime minister
# David Bowie: host
# John McCririck: broadcaster
# Niven: actor
# Teri Hatcher: actress
# Kevin McDonald: director
# Kinsey: actor
# Letwin: mp
# Don Cheadle: actress
# Anita Dobson: actress
# Christopher Lee: singer
# D'Souza: director
# Britney Spears: singer
# Johnny Depp: host
# Jamie Foxx: singer
# Charles Gant: editor
# Tony Blair: journalist
# James Hardy: correspondent
# JRR Tolkien's: director
# Usher: presenter
# Owain Bennallack: editor
# Sienna Miller: actress
# Livingstone: mp
# Sandra Dee: actress
# Chris Smith: reporter
# Kate Winslet: presenter
# Thorpe: pm
# Gear: host
# Alan Alda: actor
# Adam Vaughan: editor
# Ana Geislerova: actress
# Michael Deppler: director
# Tim Dams: editor
# Adrian Palmer: director
# Joel Ross: dj
# Campbell-Savours: prime minister
# Moreno: actress
# McCririck: actor
# Holiff: singer
# Shirlie: singer
# Russell Crowe: actress
# Bernal: actor
# Frank Arnesen: director
# Neil O'Brien: director
# Nelly: actor
# Mandaric: director
# Ian Curtis: singer
# Judi Dench: actor
# Ferguson: singer
# John Frankenheimer: actor
# Kevin Wallace: producer
# Cook: mp
# Kate Allen: director
# Bez: singer
# Imelda Staunton: singer
# Charlize Theron: actress
# Hector: actor
# Christopher Reeve: actor
# Graeme Oxby: director
# Macbeth: actor
# Hughes: actress
# Rennard: reporter
# Bert Roberts: director
# Yulia Tymoshenko: prime minister
# Niven: producer
# Robert Blake: actor
# Jean-Michel Jarre: musician
# Geoff Graber: director
# Jeff Randall: editor
# Michael Pointon: broadcaster
# Brittany Murphy: actress
# Callaghan: prime minister
# Martin Scorsese: actress
# Jose Leibovich: director
# Thomas Haden Church: director
# Youssou N'Dour: musician
# Elliot: actor
# Sidney Skolsky: actress
# George Raft: actor
# Darin: actress
# John Houlihan: editor
# Michael Jackson: reporter
# Mohammed Khatami: reporter
# Tim: host
# Robert Kilroy-Silk: host
# Silvio Berlusconi: prime minister
# Nathalie Press: actress
# Ian Brown: singer
# Gerard Jugnot: actor
# Sayeed: mp
# Mandelson: director
# Lee: actor
# Jools Holland: producer
# Karen Brady: director
# Brad Bird: actor
# Haydn Gwnne: actor
# Parmjit Singh Gill: mp
# Nelly: presenter
# Jamie Cullum: host
# Keaveney: actress
# Vanessa Paradis: singer
# Gerard Depardieu: actor
# Natalie Portman: presenter
# Evans: producer
# John Sidgmore: director
# Kristin King: musician
# Charles Gant: actress
# Lee Rainie: director
# Maggie Cheung: actress
# Mark Brailey: director
# Spacey: singer
# Vince Vaughn: actress
# Mathieu Amalric: actor
# Roger Taylor: drummer
# Vic Galloway: presenter
# Jack Cunningham: mp
# Mario Kombou: producer
# Margaret Thatcher: mp
# Harry Secombe: actress
# Martin Scorsese's: director
# Phoebe: producer
# Quentin Davies: mp
# Tim Dams: actress
# Mary Poppins': actress
# Superman: actor
# Anita Dobson: presenter
# Terry Brady: director
# David "Fathead" Newman: musician
# Mark Dornford-May: director
# Fergie: singer
# Jerry Springer: host
# Ronan Keating: singer
# Foxx: actor
# Butler: editor
# J-Lo: singer
# Steven Gaydos: editor
# John Porter: director
# Hague: mp
# Heather Craney: actress
# Drew Barrymore: actress
# Abdellatif Kechiche: actress
# Huw Stephens: dj
# John Palmer: director
# Catalina Sandino Moreno: actress
# Dick Clark: host
# Darin: actor
# Alan Milburn: prime minister
# Hans Christian Andersen: musician
# Buddy Guy: guitarist
# MacDonell: editor
# Marcello Viotti: director
# Lawrence Tucker: director
# David Davis: mp
# Bruce Forsyth: host
# Judy Craymer: producer
# Livingstone: reporter
# Martin Bell: mp
# Woodward: prime minister
# Tom Brokaw: anchor
# Sylvester: actor
# Max Carlish: musician
# Dave Collins: director
# Ferguson: host
# Dallas Roberts: actor
# Theo van Gogh: director
# Harlin: producer
# Boris Johnson: mp
# Jean-Pierre Jeunet: actress
# Benny Goodman: musician
# Presley: producer
# Michael Jackson: producer
# Andy Parfitt: dj
# Armistead: editor
# Thabo Mbeki: prime minister
# Manfred Mann: singer
# Fatboy Slim: dj
# Jordan Bratman: singer
# Tom Hanks: director
# Andrew Gilligan: reporter
# Bob Hardy: drummer
# Blanchett: actress
# Gerry Anderson's: director
# Greg Mills: director
# Mikko Hypponen: director
# Toby Stephens: actor
# Juliette Binoche: actress
# Clark: producer
# Mike Leigh's: actress
# Day-Lewis: actor
# Tony Blair: editor
# Cate Blanchett: actress
# Andy Anson: director
# Scarlett Johnson: actress
# Trapp: actress
# Keith Richards: guitarist
# Hermione: actor
# Adarsh: actor
# Jim Carrey: actor
# Big Boi: dj
# Davis: actress
# Gary Dunn: director
# Casey: singer
# Nigel McCune: musician
# Henry Fonda: actor
# Renee Zellweger: actress
# Richard Allan: mp
# Hague: pm
# Al Jolson: singer
# Miller: reporter
# Ray Charles: actress
# Norman Brennan: director
# Farrell: actor
# Roland de Marigny: host
# Caroline Langrishe: actor
# Hugues Charbonnier: director
# Kelly: mp
# Bosworth: actress
# Heather Craney: actor
# James Bond: actor
# Scorsese: actor
# Tony Blair: prime minister
# John Howard: prime minister
# Robin Broke: director
# Tyler: prime minister
# Roger Godsiff: mp
# Sandra Pires: singer
# Stanley Gold: director
# Virginia Madsen: actress
# Kevin Spacey: director
# Warnock: host
# Philip French: director
# Shannon Noll: singer
# Steven Gaydos: actress
# Helen Mirren: actor
# Owen: reporter
# Anthony Minghella: director
# Paul Rees: editor
# Carpenter: director
# Tolkien: producer
# Gavyn Davies: reporter
# Bening: director
# Ken Livingstone: mp
# Dan Peppe: dj
# Alyn Hockey: host
# Howard Hughes: presenter
# Hank Williams Jr.: singer
# Clive Owen: director
# Hugh Laurie: actor
# Holme: prime minister
# Toby Stephens: producer
# Hilary Swank: director
# Reeves: actor
# Terry Palmer: actor
# Joshua Marston: director
# Meryl Streep: actor
# Joe Pasquale: host
# Miranda Richardson: actor
# Keanu Reeves: actress
# Armand Marie Leroi's: editor
# Blair: correspondent
# Tatiana: actress
# Mel Gibson: director
# Becky Sharp: actress
# Melcher: actress
# Alan Bennett: actress
# Marley: musician
# Oliver Stone: director
# Howard Weitzman: singer
# Vicky Young: correspondent
# Meighan: guitarist
# Marie Leroi's: director
# Arnesen: director
# Fry: actor
# Jamelia Davis: singer
# Keith Edelman: director
# Emma Thompson: actor
# Ricky Gervais': actor
# Kenzie: actress
# Rufus Norris: director
# Nicholas Hytner: actress
# Swank: actor
# Harry Hill: singer
# Mick Jagger: actor
# Mira Nair: director
# Sam Mendes: director
# Springer: host
# Sizzla: singer
# Stephen Dyer: director
# Rodrigo de Rato: director
# Jill Finger: director
# Ross: presenter
# Murray: director
# Kennedy: mp
# Boris Johnson: reporter
# Honor Blackman: actress
# David Blunkett: mp
# Bruce Willis: actor
# Scoggins: singer
# Paul Shefrin: host
# Martin O'Neill: prime minister
# Madonna: singer
# Adams: producer
# Jamie Graham: director
# Ian Fleming: director
# Graham Coxon: director
# Tim Danton: editor
# Fearne Cotton: presenter
# Thomas Ades: producer
# Alex Kapranos: singer
# Malcolm X.: director
# Gorur Gopinath: director
# Halle Berry: singer
# Julie Cristie: actress
# Pickering: broadcaster
# Cate Blanchett: presenter
# Pete Doherty: guitarist
# Harvey Keitel: actor
# Ludovico Nitoglia: host
# Chris Edwards: guitarist
# Mike Berger: director
# James Cosgrave: director
# Andrew Nachison: director
# Ruslana: singer
# Daniel Levy: director
# Elain Gallin: director
# Fry: producer
# Sarah Mukherjee: correspondent
# Simon Jones: director
# Masahiro Matsuoka: actor
# Mirza: host
# Bryn F&#244;n: singer
# Monica Chadha: reporter
# Edward: mp
# Edward Leigh: mp
# Joel Ross: host
# Rick Dean: director
# Wendy Ide: director
# Simpson: director
# Victoria Hamilton: producer
# Jacques Dutronc: singer
# Andi Peters: producer
# Imelda Staunton: director
# Campbell: journalist
# Aguilera: singer
# Antonia Bernath: actress
# Stat Quo: dj
# Rob Da Bank: dj
# James Allen: director
# Merionnydd Nant Conwy: mp
# Jolin: actress
# Jol: director
# Patrick Mercer: mp
# Olivier: actor
# Thomas Haden Church: actor
# Alastair Sibbald: director
# Colin Martin: editor
# Mick Jones: guitarist
# Fagin: mp
# Ken Livingstone: reporter
# Jeremy Edwards: actor
# Tautou: actress
# Woolf: director
# Walkington: director
# 50 Cent's: editor
# Geoffrey Gilmore: director
# Susan Wojcicki: director
# Marco Behrmann: director
# Harry Hill: host
# Nathan Lane: actress
# Michael Portillo: director
# Denis Hickie's: host
# Hugh Dalton: journalist
# Sandy Climan: producer
# Bill Thompson: commentator
# Ian Harris: editor
# Robert Voice: producer
# Don Mischer: producer
# Andrew Scott: actor
# Love: drummer
# Ant: presenter
# Wigley: director
# Brown: correspondent
# Roche: mp
# Howard Stern: dj
# Shami Chakrabarti: director
# Blake Lee-Harwood: director
# Annabelle Wallace: actress
# David Furnish: singer
# Madonna: host
# Harry Connick Jr: singer
# Russell Simmons: producer
# Robert Kilroy-Silk: mp
# Yushchenko: prime minister
# George Foulkes: mp
# Honor Blackman: presenter
# Alan White: drummer
# Frank Capra: host
# Danniella Westbrook: actress
# Jeffrey Richards: singer
# Andrew Collins': guitarist
# Cash: singer
# Olivier: producer
# Bruce Snyder: actor
# Jamelia: actor
# Alyn Hockey: director
# Brown: singer
# Charles: producer
# Jonathan Ross: director
# Abbas: prime minister
# Emma Pike: director
# Malik: mp
# Rafik Hariri: prime minister
# Stephen Jakobi: director
# Troy: director
# Chris Panayis: director
# Huw Stephens: host
# Paul Rodgers: singer
# Cyril Fletcher: broadcaster
# Ellie Parker: actress
# Li Ruigang: broadcaster
# Sheppey: mp
# Lucie Silvas: singer
# Patti Smith: host
# Aburizal Bakrie: reporter
# Falconer: mp
# Livingstone: journalist
# Kapranos: musician
# Margaret Moran MP: mp
# Ted Kessler: editor
# Kevin Campbell: singer
# Janet Street-Porter: singer
# Andrew Scott: producer
# Micha Barton: director
# Peter Knight: director
# Dee: actor
# Brian Harvey: actress
# Tim Osborne: director
# Ryan Philippe: actor
# Haile: director
# Clive Owen: actress
# Robert Evans: producer
# Louise Ellman: mp
# Williams: director
# Tom Hanks: actor
# Kilroy-Silk: host
# David Roberts: editor
# Craig Prater: director
# Scott Bakula: actor
# Nicolas Cage: actor
# Mike Nichols': actress
# Peter McCormick: director
# Peston: prime minister
# Zombic: director
# Sophie Okonedo: actress
# Blair: broadcaster
# Howard: host
# Johnny Depp: actor
# McFadyen: presenter
# Rimmer: director
# Duran Duran: editor
# Obie Trice: dj
# Rufus Norris: actress
# Linda Knox: director
# Bob Laxton: prime minister
# Robert Plant: singer
# Galloway: mp
# Ellen Simonetti: director
# Steve Flack: host
# Milt Jackson: musician
# Cliff Richard: dj
# Gwen Stefani: singer
# Taylor: director
# Max Bobbitt: director
# Mendis: reporter
# Ned Temko: editor
# Richard Gere: host
# Jackie Stallone: dj
# Gillian Anderson: director
# Warren Gatland: director
# DiCaprio: actress
# Jamie Graham: actress
# Emily Eavis: editor
# Kevin Spacey: actor
# Michael Howard: reporter
# Philip French: actor
# Sigarchi: reporter
# Frank Field: prime minister
# John Westwood: director
# Christine Milian: singer
# Bannatyne: host
# Brown: host
# Kelly Reilly: actress
# Angie Errigo: director
# Clare Higgins: director
# Liverpool: prime minister
# Elton John: singer
# David Caldwell: director
# Oliver Finegold: mp
# William Hague: mp
# George Galloway: mp
# Ziyi Zhang: actress
# Hilary Swank: actor
# Naomi Watts: actress
# Peel: dj
# Arvind Parmar: host
# Rick Rubin: producer
# Dennis Quaid: actor
# Doris Day: actress
# Joni Lovenduski: mp
# John Carvel: journalist
# David Bedford: director
# Jackson: journalist
# AL Gooneratne: director
# Kinsey: actress
# Matthew Perry: actor
# Campbell: prime minister
# Anil: director
# Joel Silver: producer
# Craig Watson: director
# Lord Callaghan: pm
# Strachan: director
# Andrea Arnold: presenter
# Maria Cruz: actress
# Roger Michell: director
# Janet Street-Porter: host
# Michael London: producer
# Nick McCarthy: singer
# Sophie Okonedo: actor
# Evan Davis: editor
# Viktor Yanukovych: prime minister
# Carol Mendelsohn: producer
# Anthony McPartlin: host
# Hussein Chalayan: director
# Katharine Hepburn: actress
# Anne Robinson: presenter
# Jenifer: singer
# Rob Fahey: editor
# Mike Leigh: director
# William Plante: director
# Parker: director
# Patrick Walden: guitarist
# Jugnot: actor
# Ali Smith: director
# Elfyn Llwyd: singer
# Colin Martin: presenter
# Kidman: reporter
# Jennie Bond: correspondent
# the Rat Pack: director
# Smith: mp
# Fiona Deans: director
# Gene Kelly: singer
# George Gregan: host
# Matthew Vaughn: actress
# Leslie: prime minister
# Julia Roberts: actress
# Lorraine Kelly: editor
# Christopher Lee: actor
# Judi Dench: actress
# Maria: actress
# Jamie Foxx: actor
# Billy Elliot: actor
# Simon Perry: editor
# Thorpe: prime minister
# Robbie Savage: director
# William Hague: pm
# William Hill: actress
# John Prescott's: correspondent
# Hailey: producer
# Orson Welles': actor
# Ewan McGregor: actor
# Ben Whishaw: actor
# Ryuhei Kitamura: director
# Rob Pollard: director
# Sunil Mendis: reporter
# Sam Endicott: singer
# Bruce Forsyth's: prime minister
# Reese Witherspoon: actress
# Mel Gibson: producer
# Harry Belafonte: singer
# Rodgers: guitarist
# Nicole Kidman: actress
# Ray Charles: musician
# Aynsley-Green: director
# Charles Hazlewood: director
# Macduff: actor
# McFadden: singer
# Merrin: director
# Leonardo DiCaprio: host
# Mr Prescott: prime minister
# Graham Norton: host
# Gallagher: singer
# John Lydon: singer
# John Prescott: pm
# Rufus Norris: producer
# Baume: prime minister
# Wendy Ide: actor
# Ed Graczyk: director
# Michael Mann: producer
# Simpson: actor
# Rock: host
# Bez: actor
# Imelda Staunton: actor
# Lorimer: director
# Gervais: actor
# Jamie Graham: presenter
# Mikhail Khodorkovsky: commentator
# Digby Jones: director
# Christine Rush: director
# West: producer
# Graham Barlow: editor
# Mahinda Rajapakse: prime minister
# Caprice: actor
# Greg Dyke: reporter
# Holme: broadcaster
# Sara Forestier: director
# Terry Melcher: producer
# Usher: singer
# Prescott: prime minister
# Wenger: director
# Ossie Davis: actor
# Jonathan Ross: actress
# O'Connor: director
# Annie Walker: director
# Rob Da Bank: host
# Justin Timberlake: singer
# Livingstone: prime minister
# Alastair Campbell: director
# Heather Graham: actor
# Condoleezza Rice: prime minister
# R Kelly: singer
# Bruce Davis: director
# Wilson: mp
# Ken Loach: director
# Jon Thoday: producer
# Robert Peston's: prime minister
# David Arnold: singer
# Benoit Poelvoorde: actor
# Kate Beckinsale: actress
# Anne Thompson: reporter
# Felicity Huffman: actress
# Ken Livingstone: journalist
# Tess Daly: actress
# Brian May: guitarist
# Michael Moore: director
# Stanley Townsend: actor
# Norman Cook: dj
# Clapton: guitarist
# Alan Wass: musician
# Chum: reporter
# Clive Owen's: actor
# Eastwood: editor
# William Hill: actor
# Tommie Bergman: director
# Zach Braff: director
# Oleg Rybachuk: prime minister
# Staunton: editor
# Mark Tuffy: director
# Foxx: actress
# Maggie Gyllenhaal: actress
# Moore: editor
# Fletcher: broadcaster
# Matt LeBlanc: actor
# Cathy Freeman: actor
# Quinn: mp
# Southan Morris: director
# Archer: mp
# Roddick: host
# Hugh Grant: actor
# Gary Lightbody: drummer
# Brigitte Nielsen: actress
# Kenny Jones: drummer
# Nicky Wire: guitarist
# William Lerach: director
# Claudia Schiffer: director
# Tony Christie: singer
# Christian Slater: actor
# Philip Pullman's: director
# Ian Curtis: producer
# Milburn: prime minister
# Stallone: actor
# Diane Abbot: mp
# Bratman: singer
# Bruvik: host
# Cliff Richard: singer
# Fatos Nano: prime minister
# Prater: director
# Stephen Daldry: director
# Mike Goodridge: editor
# Fearne Cotton: editor
# Blair: mp
# Brown: director
# Vera Drake: singer
# Paul Adams: correspondent
# Jerry Scoggins: musician
# Pasquale: host
# Morgan Freeman: director
# Ampas: producer
# Liam Neeson: director
# Paul Jones: singer
# Rodrigo Rato: director
# Bernardo Bertolucci's: actor
# Clifford Alexander: director
# Amanda Ross: producer
# Mann: director
# Kite: singer
# Maurice Watkins: director
# Nelly: singer
# Jonathan Ross: actor
# Janie Hendrix: guitarist
# Saint-Andre: director
# Aishwarya Rai: actor
# Marc Rothemund: director
# Sofia Coppola: director
# Jose Maria Pons: director
# Guillem Balague: journalist
# Toni Munoz: director
# Emily Eavis: presenter
# Paddy Considine: actor
# Madden: musician
# Curt Hopkins: director
# Thaksin Shinawatra: prime minister
# Campbell: presenter
# Phil Jupitus: guitarist
# Emma Watson: actor
# Blairs: prime minister
# Nachison: journalist
# Philippe Saint-Andre: director
# Deirdre Clancy: actor
# Chirac: reporter
# Chris Curry: director
# Dougray Scott: actor
# Richard Ayers: director
# George C Scott: actor
# Peter Ainsworth: mp
# Michael Collins: actor
# Mary Poppins: director
# Andrew McFadyen: journalist
# Jackson: prime minister
# Abdullatif Sener: prime minister
# Alfonso: producer
# Conti: director
# Partridge: musician
# Carson: presenter
# Thaksin Shiniwatra: prime minister
# Rob Andrew: director
# Joe Cocker: commentator
# David Monteith: director
# Boris Johnson: editor
# Arash Sigarchi: journalist
# Antonio Fargas: actor
# Staunton: actress
# Alexei Sayle: director
# Tennessee Williams: actor
# Scarlett Johansson: actress
# Blair: pm
# Hague: prime minister
# Sir Richard Eyre: director
# John Mayer: singer
# Helen Mirren: actress
# Michael Jackson: singer
# Karin Viard: actress
# Rodgers: drummer
# Elvis: singer
# Tim Ellsmore: director
# G Money: presenter
# Love: musician
# Brenda Blethyn: actor
# Liam Fox: host
# Declan Donnelly: host
# Amit Yoran: director
# Pepsi: singer
# Martin Clunes: actor
# Dieter Kosslick: director
# Brosnan: director
# Janet Jackson: singer
# Tess Daly: presenter
# Nair: actress
# Al Jolson: actor
# Mutu: director
# Mike Leigh: actress
# Kurt Opsahl: reporter
# Alan Johnson: mp
# Meryl Streep: actress
# Ryan Seacrest: presenter
# Kilroy-Silk: mp
# Elliott Wilson: editor
# Paul Giamatti: actor
# George Michael: singer
# Joel Schumacher: director
# Natalie Appleton,31: singer
# Tony Blair's: prime minister
# James Honeyman-Scott: guitarist
# Nigel Roberts: director
# Lord Janner: mp
# John Sergeant: host
# Deirdre Clancy: producer
# Mike McGuire: director
# Burke: broadcaster
# Leonardo DiCaprio: director
# Brian Grazer: producer
# Sarah Teather: mp
# Andrew Mehrtens: host
# Edward: director
# Howard: mp
# Heath: prime minister
# John Binks: director
# Peter Luff: mp
# Rodrigo de la Serna: actor
# Emilio Butragueno: director
# Vera Drake: host
# McLetchie: correspondent
# Swank: actress
# John Molloy: host
# Germaine Greer: producer
# Wendy Day: reporter
# Ashvin Kumar: presenter
# Michael Mates: mp
# Sandra den Hamer: director
# Angie Errigo: actor
# Clare Higgins: actor
# Victoria Hamilton: actress
# Shaun Ley: correspondent
# Dan O'Herlihy: actor
# Brian May: drummer
# Andy Clarke: director
# David Learmount: editor
# Liam Gallagher: drummer
# Karen Buck: mp
# Conor McNicholas: editor
# David Lammy: mp
# Asif Zardari: prime minister
# Caroline Quentin: actress
# Slater: actor
# Larry Mullen Jr: drummer
# Alicia Keys: singer
# Ash: director
# Kevin McDonald: actress
# Blair: reporter
# Ffion: mp
# Archer: actor
# Anjelica Huston: actor
# Stephen Cape: correspondent
# Richard Eyre: director
# Brown: mp
# Spector: actress
# Clint Wheelock: musician
# Marcus Hawkins: editor
# Nicky Wire: drummer
# Connick: singer
# Flicker: guitarist
# Mike Leigh: actor
# John Pavlik: director
# Reg Carr: director
# Radwan Hadi: director
# Aragones: reporter
# Richard Griffiths: actor
# Robert Quinn: director
# Geordie: host
# Ken Livingstone: prime minister
# Stephen Mear: actor
# Mark Mardell: correspondent
# Peter Sellers: actor
# Butters: host
# Howard: pm
# Geoff Hoon: prime minister
# Richard Black: correspondent
# Ray: director
# Madonna: actor
# Robert Redford: actor
# Manic
#
# Richey Edwards: guitarist
# Jennifer Lopez: singer
# Bernie Grant: mp
# Charles Manson: actress
# Chris Rock: host
# James Dean Bradfield: singer
# Frank Lloyd: host
# Goldsmith: mp
# Margaret Hassan: mp
# Blake: actor
# Halle Berry: actor
# Mercury: singer
# Beyonce: singer
# Jerry Lewis: actor
# Kate Moss: singer
# Barbara Walters: anchor
# Clark: host
# Aaliyah: producer
# Shane Richie: actor
# Ephraim Inoni: prime minister
# Thomas Haden Church: actress
# John Howard: pm
# Flic Everett: journalist
# Amma Asante: director
# Daniel Sandford: correspondent
# Kelly: actress
# Stiles Kellett: director
# Manmohan Singh: prime minister
# Lillian Tan: director
# Miles Davis: musician
# Tony Banks: mp
# Jamie Foxx: director
# Wenger: reporter
# Gil Cates: reporter
# Diane Kruger: director
# Nigel Melville: director
# Paul Trotter: editor
# E Nesbit: singer
# David Blunkett: prime minister
# Jacques Dutronc: actor
# Bennett: director
# Spike Lee: director
# Considine: actor
# Nicki Chapman: host
# Jonny Quinn: drummer
# Richard Griffiths: producer
# Marc Forster: director
# Bobby Darin: singer
# Barbara Castle: prime minister
# Barry Nelson: actor
# Stephen Mear: producer
# Cheadle: actor
# Barbara Broccoli: producer
# Wes Butters: dj
# Roy Disney: director
# Straw: journalist
# Sayeeda Warsi: mp
# Dan Brown: director
# Stefani: singer
# Budd Schulberg: actor
# Balls: mp
# Frank Sinatra: director
# Howard: reporter
# Kate Winslet: director
# Reveta Bowers: director
# Tom Heap: correspondent
# Carla Ferstman: director
# Fidelis Nanga: journalist
# Trapp: singer
# Roger Bennett: director
# Floella Benjamin: presenter
# Peter Chelsom: director
# Jackson: singer
# Carl Gavin: director
# Ronaldinho: journalist
# David Dunne: prime minister
# Deeley: presenter
# Bates: director
# Gael Garcia Bernal: actor
# Ray Charles: singer
# Patsy Rowlands: actress
# David Cameron: mp
# Ian: prime minister
# Lynn Franco: director
# Charles Evans Jr: producer
# Oliver Irish: editor
# Jeannie Kedas: broadcaster
# Butters: broadcaster
# Bowers: director
# Allen Weiner: director
# Steve Linford: director
# Brown: reporter
# Shakespeare: actor
# Harry Connick Jr: actor
# Trevor Nelson: editor
# Verroken: director
# Yvonne Todd: director
# Robert Peston: journalist
# Richard Gere: actor
# Jay-Z.: singer
# Opsahl: journalist
# Jeremy Irons: director
# Godzilla: actor
# Krist Novoselic: drummer
# Graham Coxon: guitarist
# Steven Dowell: actor
# Watson: director
# Laura Michelle Kelly: director
# Raymond Watson: director
# Jeffrey Richards: actor
# Vera Drake: director
# Gil Cates: producer
# Andrew Burke: broadcaster
# Morgan Freeman: actor
# Alan Bennett: singer
# Shimon Peres: prime minister
# Carl Aycock: director
# Colin Martin: dj
# Liam Neeson: actor
# Alejandro Amenabar: director
# Dominic Hirsch: director
# John Peel: presenter
# Leigh: director
# Willis: actor
# Ry Cooder: producer
# Jack Rowell: director
# Nigel Whalley: director
# Kenzie: singer
# Elliot Grove: director
# Flicker: drummer
# Michael Coogan: director
# Barrie: director
# Courtney Love: singer
# Michael Howard: prime minister
# Dubs: mp
# Hutt: mp
# Daniel Auteuil: actor
# Andrew Marr: editor
# JK: dj
# Leonardo DiCaprio: actress
# Graham Norton: actress
# Peter Hunt: correspondent
# Martin: mp
# Hendrix: guitarist
# Mahmoud Abbas: prime minister
# Colin Farrell: actor
# Charles: singer
# Akira Kurosawa: director
# Trevor McDonald: actor
# Kate Hoey: actor
# Mary Poppins: actor
# Don Cheadle: director
# Conor McNicholas: presenter
# Cate Blanchett: host
# Anne Keothavong: host
# Weitz: director
# Conte: director
# Judith Areen: director
# Tom: actor
# Jonathan Dimbleby: host
# Peter Caruana: director
# Dogville: director
# Godzilla: producer
# Alfie Moon: actor
# Peter Schoonen: editor
# Sienna Miller: director
# Mubanga: director
# Jeffrey Richards: producer
# Wilkinson: actor
# Philip French: actress
# Lammy: editor
# Ruth Kelly: mp
# Barry Sheerman: mp
# Javier Bardem: actor
# Woodward: host
# Taylor Hackford: director
# Bening: actress
# Howard Flight: mp
# Conleth Hill: director
# Michael Douglas: director
# Mark Taylor: director
# Frank Capra's: producer
# Mann: producer
# Kevin Bacon: actor
# George Clooney: singer
# Nick Davies: director
# Hilary Swank: actress
# Paul Thomson: drummer
# Jonny Evans: editor
# Sean McAllister: director
# Redknapp: director
# Joshua Marston: actress
# Kurt Opsahl: journalist
# Jones: host
# Hugh Jackman: actor
# Andrew Burke: director
# Diego El Cigala: singer
# Matthew Turnbull: director
# Jeremy: prime minister
# Mark Hughes: host
# Carol Smillie: presenter
# Nelson Mandela: actor
# Leonardo DiCaprio: actor
# Edward: actor
# Michael: singer
# Chris Hawkins: host
# Andrew Foster: director
# Mary Poppins: producer
# Martin Scorsese: director
# Keanu Reeves: host
# Sean Moore: drummer
# Michael Martin: mp
# Elton John: actor
# Andrew Ridgeley: singer
# Max Carlish: singer
# Paul Gascoigne: actress
# John Cryer: mp
# Sam Mendes: actress
# Carole Walker: correspondent
# Lord Callaghan: prime minister
# Moya: host
# Danny Williams: host
# Hayao Miyazaki: director
# Love: singer
# Phil Davis: actress
# Peter Jackson: director
# Ant: host
# Lewis: mp
# Pete Farndon: guitarist
# Simon Hall: correspondent
# Ashley Bird: editor
# Feargal Sharkey: singer
# Peter Duncan: mp
# AR Rahman: director
# Yang: reporter
# King: dj
# Smernicki: singer
# Mark Mackie: director
# Edward Fox: actor
# Blair: journalist
# Gwen Stefani: presenter
# Stephen Merchant: actor
# Jamie Foxx: actress
# Diane Kruger: actress
# Brian McFadden: singer
# Younger: prime minister
# Laah Chong-gyu: director
# Charles Gant: director
# Okonedo: actress
# Alan White: singer
# Sandra Bullock: actor
# Edna Mode: director
# Gavin Patterson: director
# Frank Field: mp
# Margaret Beckett: pm
# Jean-Claude Van Damme: director
# Chris Smith: mp
# Nancy Sinatra: singer
# Doug Smith's: mp
# Stern: dj
# Howard Hughes: director
# Anshuman Magazine: director
# Michael Ancram: mp
# David Martin: director
# Curry: host
# Dominic Wood: presenter
# Simon McBurney: director
# Michael G Wilson: producer
# Emily Eavis: dj
# Tim Dams: director
# O'Driscoll: host
# Gene Kelly: actor
# Federer: journalist
# Richard Dreyfuss: actor
# William Hague: prime minister
# Andy Stephens: director
# Ray: actor
# Wendy Ide: actress
# Thatcher: prime minister
# Ruby Dee: actress
# Ambrose Bierce: singer
# Kalusha Bwalya: director
# Richard Moffat: director
# Shogo Tomiyama: producer
# Danny Shaw: correspondent
# Bez: actress
# Chris Paterson: host
# Imelda Staunton: actress
# Duncan Ingram: director
# Ian McCartney: mp
# Paul Abbott: actress
# David Walliams: actor
# Jack Boorman: director
# Van Morrison: commentator
# Ronan O'Gara: host
# George Clooney: host
# Blunkett: mp
# Jamie Foxx: reporter
# Gordon Brown: mp
# Robert Peston: prime minister
# Selma Blair: actor
# Cynthia Cooper: director
# Cat Deeley: host
# Roger Clarke: director
# Yeats: actor
# Mick Mars: guitarist
# Kanye West: singer
# John Prescott: prime minister
# Charles Elson: director
# Trevor Nelson: presenter
# Peter Fish: director
# John Gill: director
# Charles Kennedy: mp
# David Stanley: director
# Phil Davis: actor
# Bruni Sablan: musician
# Noah Baumbach: director
# David Frost: director
# Joel: dj
# Ian McShane: actor
# Pete Doherty: singer
# Edward Germano: producer
# Frank: host
# Collins: director
# Claire: columnist
# Renny Harlin: director
# Matthew Warchus: director
# Hamish MacDonell: journalist
# Diane Kruger: actor
# Sam Raimi: director
# Nick Ross: editor
# Ron Howard: director
# Robert Jackson: mp
# Debra Hill: producer
# Blanchett: director
# Boy George: dj
# Laura Michelle Kelly: actress
# Spike Lee: actor
# Alex Kapranos: musician
# Alastair Campbell: journalist
# Vera Drake: actress
# Vanessa Paradis: actress
# Kapranos: mp
# Mike Leigh's: director
# Zoe Ball: presenter
# Edgar Allan Poe: singer
# Kevin Krewell: editor
# Phil: director
# Wilbur: actor
# Richard Dreyfuss: producer
# Usher: actor
# Cate Blanchett: director
# Samuel Barnett: actor
# Dan Brown: actor
# Clint Eastwood: director
# Wes Butters: host
# Kate Winslet: actor
# Francesco Galesi: director
# Christopher Karloff: guitarist
# Meibion Glyndwr: mp
# Davis: director
# Christina Aguilera: singer
# Humphrey Bogart: singer
# Dan Ashcroft: columnist
# Viotti: director
# Will Smith: singer
# Lucas: actor
# Dan Rather: anchor
# Daniel Day-Lewis: actor
# Alan Parker: director
# Barry Weissler: producer
# Graham King: producer
# Ray Charles: director
# Patti Smith: director
# McFadden: presenter
# Gordon Brown: pm
# Tim Dean: director
# Umaga: host
# Jo Flaherty: broadcaster
# Blears: prime minister
# Hussein Chalayan: guitarist
# John Bryson: director
# Spurlock: producer
# Martin Campbell: director
# Steven Gaydos: director
# Alexander Payne: actor
# Bob Angus: director
# Quentin Tarantino: director
# Bond: director
# Beth Gibbons: singer
# Geoffrey Rush: actor
# Prescott: mp
# Mark Sparrow: editor
# Jeremy Paxman: presenter
# Troy: actress
# Robin Cook: journalist
# Gordon Prentice: mp
# Glenn Campbell: correspondent
# Paul Woolstenholmes: mp
# Campbell-Savours: mp
# Brown: journalist
# Schrader: director
# Jimmy: director
# Oliver Finegold: reporter
# Paul: prime minister
# Jeremy Irons: actor
# Paule Constable: actor
# Jackie Stallone: actor
# Laura Michelle Kelly: actor
# Alex Kapranos: guitarist
# Micha Barton: actress
# Oliver Letwin: mp
# Jean Reno: actor
# Bruce Forsyth: presenter
# Nigel Waterson: mp
# Pete Mitchell: dj
# Vera Drake: actor
# Alan Bennett: director
# Jeffrey Matsuura: director
# Lee Evans: actor
# Tim Kash: host
# Mark Morrison: singer
# Keith Vaz: mp
# Peter Williams: director
# Scholls: director
# Natalie Portman: actor
# Portman: actress
# Jim Taylor: director
# Nicholas Hytner: director
# Lopez: director
# Rupert Lowe: director
# Mantooth: guitarist
# Mike Leigh: editor
# Blair: editor
# Miles Shipside: director
# Green Lantern: dj
# Moazzam Begg's: mp
# Tony Wilson: producer
# Barbara Stocking: director
# Lars Von Trier: director
# Ken Macdonald: director
# Cedric Gibbons: director
# King: singer
# Pharrell Williams: singer
# Bill Oddie: prime minister
# Philip: director
# Taha Idris: director
# Twista: actor
# Paul Boateng: mp
# Steve Winwood: commentator
# Jackie Ballard: mp
# Bonny Lee Bakley: actor
# Missy Higgins: singer
# Bill Berry: drummer
# Queen Latifah: producer
# Bob Geldof: singer
# Don Cheadle: actor
# Simon Fuller: reporter
# Charles Williams: producer
# Blair: prime minister
# Fran Cosgrave: host
# Meyer: mp
# Kudrow: producer
# Maria: singer
# Betty Astell: actress
# Knight: singer
# Osbournes: singer
# Sandra Pires: actress
# Max Jones: director
# Clark Boyd: correspondent
# Gillian Anderson: actress
# Paule Constable: producer
# Quincy Jones: producer
# Johnson: mp
# Laura Michelle Kelly: producer
# Fearne Cotton: dj
# Matthew Bourne: actor
# Ken Loach: guitarist
# Harry Potter: director
# Yolande Moreau: actress
# Lee Evans: producer
# Michael Gambon: actor
# Phil Spector: producer
# Pierce Brosnan: actor
# Chris Rock: actor
# Angie Errigo: actress
# Clare Higgins: actress
# Conleth Hill: actor
# Michael Douglas: actor
# Jane Birkin: singer
# Matt Lucas: actor
# S Hussain Zaidi: journalist
# Bashir: journalist
# Fox: reporter
# Callaghan: pm
# Walden: singer
# Jackson: mp
# BB King: guitarist
# Gary O'Donoghue: correspondent
# Conti: musician
# Lim: presenter
